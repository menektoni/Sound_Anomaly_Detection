# %% [markdown]
# ### Download model and getting the output we want

# %%
mymodel = keras.models.load_model('my_model73.h5')
mymodel.trainable = False

# %%
new_model = models.Sequential([keras.Input(shape=(128, 217, 1))])

# %%
#Range(9) for cube-shaped output, Range(10) for vector-shaped output
for i, layer in zip(range(9), mymodel.layers):
    new_model.add(layer)

# %%
new_model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 128, 217, 32)      320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 217, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 108, 32)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 108, 64)       18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 108, 64)       36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 54, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 54, 128)       73856
# ...

# %%
#on el X_test1D s'ha de posar el dataset del MIMII amb el que volem entrenar despres l'autoencoder
output = new_model.predict(X_test1D)

# %%
output
# Out:
# array([[[[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 1.00296173e+01, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 9.58670425e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 1.25353603e+01, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           3.26910362e+01, 2.50530219e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
# ...

# %%
#S'ha de guardar aquest output per despres entrenar l'autoencoder
